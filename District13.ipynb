# %% [markdown]
# <a href="https://colab.research.google.com/github/stinkymatt/pub/blob/master/District13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataStax Ship Team Hackathon
# Team: District 13
#
# This notebook connects to an Astra database and pulls data from it.
#
# It uses the Cassandra Python driver, so it needs a secure-connect-bundle.
# It can pull that from the GCP Secret Manager, or you can upload a secure-connect-bundle in the Filemanager on the left. Name it **scb.zip**.
#
# You'll also need a client_id and secret for a read-only role. If you downloaded the GeneratedToken.csv file from Astra, you can either upload that, or fill in the field values below.

# %%
#Run me first to install the dependencies
# !pip install google-cloud-secret-manager
# !pip install astrapy
# !pip install cassandra-driver

# %% [markdown]
# Below are the settings for our database that are NOT sensitive.

# %%
#config
ASTRA_DB_ID='21107608-ec56-472e-90cf-95ac419e5d7c' #could make an API call to get these //TODO
ASTRA_DB_REGION='us-east-1'
ASTRA_DB_KEYSPACE='district13'
proj_name='gcp-product-401-dev'
secret_name='dist13org'
path_to_secret = f"projects/{proj_name}/secrets/{secret_name}/versions/latest"

# %% [markdown]
# You do not need to run the next section if you have uploaded an Astra Secure Connect Bundle named "scb.zip"
#
# If you do run the next section, an authentication step will prompt for an auth token. Click the link and follow the instructions, then paste the provided token back into the empty text field in the notebook output area below the cell.

# %%
#NOTE: You can also just upload the secure connect bundle by clicking the folder
#icon on the far left sidebar. Name the file scb.zip

#Get an admin secret from the GCP secret store
#Download the secure connect bundle


from google.cloud import secretmanager
from google.colab import auth
#This line will start a dialog below, follow instructions to authenticate
auth.authenticate_user() 
#!gcloud config set project 'gcp-product-401-dev'

#This uses the GCP cloud API to fetch a secret
secret_store = secretmanager.SecretManagerServiceClient()
resp = secret_store.access_secret_version(request={"name": path_to_secret})
mysecret = resp.payload.data.decode('UTF-8')
ASTRA_DB_APPLICATION_TOKEN=mysecret

#Astra devops API to fetch secure connect bundle
from astrapy.client import create_astra_client

astra_client = create_astra_client(astra_database_id=ASTRA_DB_ID,
                                   astra_database_region=ASTRA_DB_REGION,
                                   astra_application_token=ASTRA_DB_APPLICATION_TOKEN)
zipUrl = astra_client.ops.get_secure_bundle(database=ASTRA_DB_ID)

import urllib
urllib.request.urlretrieve(zipUrl['downloadURL'], 'scb.zip')
# Out:
# adc.json  sample_data  scb.zip

# %% [markdown]
# Below, you can manually enter values for the client_id and client_secret that Astra provided. If you have NOT uploaded the GeneratedToken.csv file in the Filemanager on the left, then fill these fields out. You can use either. If the file is present, it will take precedence.

# %%
#Enter values for the client ID and client Secret
# OR 
#Upload the GeneratedToken.csv file with the file browser at left
client_id_input = "uCmtnzAThNOEfxzavDiqMDUa" #@param {type: "string"}
client_secret_input = "-3erG0ZYJSL_Q_abhdvIYF-QAsR,dczbGcyp0-uO8eqsejB7rk7QtHoAJUZvEvLZtUn4c9XFBReH63PU0LZJ40Z+hc18YGQ_689rJph1YPmhlh8fx5F2PHKoDPRd3eH_" #@param {type:"string"}
#!cat GeneratedToken.csv

# %%
#You can upload an AstraCreds.csv file in the file explorer on the left
#Otherwise you will be prompted for client_id and secret
import csv
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

#If there is no AstraToken.csv in working dir, then prompt user
def get_auth_info_from_creds():
  """
  Collect information about auth id and secred from AstraToken file
  if such file is presentin the gdrive "Colab Notebooks" folder.
  In other case it will return some hardcoded defaults.
  """
  try:
    auth_info = None
    with open('GeneratedToken.csv', newline='') as csvfile: 
      reader = csv.reader(csvfile, delimiter=',', quotechar='"')
      auth_info = [x for x in reader][1]  # 2nd line
    print("returning auth info from GeneratedToken.csv file")
    id = auth_info[0]
    secret = auth_info[1]
    token = auth_info[2]
    return id, secret, token
  except FileNotFoundError:
    print("GeneratedToken.csv not found in the gdrive, set creds manually in fields above.")
    return client_id_input, client_secret_input, None

def connect_to_astra():
  cloud_config= {'secure_connect_bundle':'scb.zip'}
  auth_prov = PlainTextAuthProvider(auth_id, auth_secret)
  cluster = Cluster(cloud=cloud_config, auth_provider=auth_prov)
  return cluster.connect()

auth_id, auth_secret, _ = get_auth_info_from_creds()
session = connect_to_astra()
electricity_data_2020 = session.execute("SELECT * FROM district13.electricity WHERE year=2017").all()
#print("Found {} countries for 2020".format(len(electricity_data_2020)))
electricity_data_2020
# Out:
# returning auth info from AstraCreds file
# Found 210 countries for 2020
# [Row(iso_code='AGO', year=2017, biofuel_electricity=Decimal('0.2'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Angola', electricity_generation=Decimal('10.676'), fossil_electricity=Decimal('2.882'), gas_electricity=Decimal('1.569'), hydro_electricity=Decimal('7.576'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.313'), other_renewable_electricity=Decimal('0.2'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('7.794'), solar_electricity=Decimal('0.018'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='VNM', year=2017, biofuel_electricity=Decimal('0.076'), carbon_intensity_elec=None, coal_electricity=Decimal('62.688'), country='Vietnam', electricity_generation=Decimal('191.222'), fossil_electricity=Decimal('102.721'), gas_electricity=Decimal('39.576'), hydro_electricity=Decimal('88.092'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.457'), other_renewable_electricity=Decimal('0.076'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('88.5'), solar_electricity=Decimal('0.009'), wind_electricity=Decimal('0.323')),
#  Row(iso_code='DEU', year=2017, biofuel_electricity=Decimal('51.0'), carbon_intensity_elec=Decimal('424.0'), coal_electricity=Decimal('241.3'), country='Germany', electricity_generation=Decimal('647.9'), fossil_electricity=Decimal('355.1'), gas_electricity=Decimal('86.7'), hydro_electricity=Decimal('20.2'), nuclear_electricity=Decimal('76.3'), oil_electricity=Decimal('27.1'), other_renewable_electricity=Decimal('51.2'), other_renewable_exc_biofuel_electricity=Decimal('0.2'), renewables_electricity=Decimal('216.5'), solar_electricity=Decimal('39.4'), wind_electricity=Decimal('105.7')),
#  Row(iso_code='STP', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Sao Tome and Principe', electricity_generation=Decimal('0.085'), fossil_electricity=Decimal('0.078'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.007'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.078'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.007'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='PNG', year=2017, biofuel_electricity=Decimal('0.039'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Papua New Guinea', electricity_generation=Decimal('3.864'), fossil_electricity=Decimal('3.033'), gas_electricity=Decimal('1.031'), hydro_electricity=Decimal('0.79'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('2.002'), other_renewable_electricity=Decimal('0.039'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.831'), solar_electricity=Decimal('0.002'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='DNK', year=2017, biofuel_electricity=Decimal('6.264'), carbon_intensity_elec=Decimal('176.0'), coal_electricity=Decimal('6.209'), country='Denmark', electricity_generation=Decimal('31.042'), fossil_electricity=Decimal('9.229'), gas_electricity=Decimal('2.018'), hydro_electricity=Decimal('0.018'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.002'), other_renewable_electricity=Decimal('6.264'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('21.813'), solar_electricity=Decimal('0.751'), wind_electricity=Decimal('14.78')),
#  Row(iso_code='PAK', year=2017, biofuel_electricity=Decimal('3.317'), carbon_intensity_elec=None, coal_electricity=Decimal('2.027'), country='Pakistan', electricity_generation=Decimal('126.3'), fossil_electricity=Decimal('84.238'), gas_electricity=Decimal('30.437'), hydro_electricity=Decimal('27.646'), nuclear_electricity=Decimal('8.109'), oil_electricity=Decimal('51.774'), other_renewable_electricity=Decimal('3.317'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('33.953'), solar_electricity=Decimal('0.889'), wind_electricity=Decimal('2.101')),
#  Row(iso_code='ERI', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Eritrea', electricity_generation=Decimal('0.367'), fossil_electricity=Decimal('0.354'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.354'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.013'), solar_electricity=Decimal('0.011'), wind_electricity=Decimal('0.002')),
#  Row(iso_code='GLP', year=2017, biofuel_electricity=Decimal('0.066'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Guadeloupe', electricity_generation=Decimal('1.649'), fossil_electricity=Decimal('1.44'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.44'), other_renewable_electricity=Decimal('0.066'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.209'), solar_electricity=Decimal('0.092'), wind_electricity=Decimal('0.051')),
#  Row(iso_code='ESH', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Western Sahara', electricity_generation=Decimal('0.0'), fossil_electricity=Decimal('0.0'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='CAN', year=2017, biofuel_electricity=Decimal('11.51'), carbon_intensity_elec=None, coal_electricity=Decimal('55.059'), country='Canada', electricity_generation=Decimal('645.224'), fossil_electricity=Decimal('112.996'), gas_electricity=Decimal('53.875'), hydro_electricity=Decimal('390.641'), nuclear_electricity=Decimal('95.131'), oil_electricity=Decimal('4.063'), other_renewable_electricity=Decimal('11.719'), other_renewable_exc_biofuel_electricity=Decimal('0.209'), renewables_electricity=Decimal('437.096'), solar_electricity=Decimal('3.538'), wind_electricity=Decimal('31.198')),
#  Row(iso_code='MNE', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('1.28'), country='Montenegro', electricity_generation=Decimal('2.391'), fossil_electricity=Decimal('1.28'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('1.014'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.111'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.097')),
#  Row(iso_code='TTO', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Trinidad and Tobago', electricity_generation=Decimal('9.336'), fossil_electricity=Decimal('9.331'), gas_electricity=Decimal('8.152'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.179'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.005'), solar_electricity=Decimal('0.005'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='OWID_WRL', year=2017, biofuel_electricity=Decimal('517.483'), carbon_intensity_elec=None, coal_electricity=Decimal('9009.211'), country='World', electricity_generation=Decimal('24570.376'), fossil_electricity=Decimal('15750.371'), gas_electricity=Decimal('5620.225'), hydro_electricity=Decimal('4075.455'), nuclear_electricity=Decimal('2543.99'), oil_electricity=Decimal('1120.936'), other_renewable_electricity=Decimal('622.176'), other_renewable_exc_biofuel_electricity=Decimal('104.692'), renewables_electricity=Decimal('6276.014'), solar_electricity=Decimal('443.315'), wind_electricity=Decimal('1135.069')),
#  Row(iso_code='RUS', year=2017, biofuel_electricity=Decimal('2.678'), carbon_intensity_elec=None, coal_electricity=Decimal('163.055'), country='Russia', electricity_generation=Decimal('1035.283'), fossil_electricity=Decimal('658.192'), gas_electricity=Decimal('484.453'), hydro_electricity=Decimal('183.163'), nuclear_electricity=Decimal('190.115'), oil_electricity=Decimal('10.684'), other_renewable_electricity=Decimal('3.113'), other_renewable_exc_biofuel_electricity=Decimal('0.435'), renewables_electricity=Decimal('186.976'), solar_electricity=Decimal('0.56'), wind_electricity=Decimal('0.14')),
#  Row(iso_code='ARE', year=2017, biofuel_electricity=Decimal('0.006'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='United Arab Emirates', electricity_generation=Decimal('126.529'), fossil_electricity=Decimal('125.788'), gas_electricity=Decimal('125.785'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.003'), other_renewable_electricity=Decimal('0.006'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.741'), solar_electricity=Decimal('0.734'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='VIR', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='United States Virgin Islands', electricity_generation=Decimal('0.523'), fossil_electricity=Decimal('0.516'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.516'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.007'), solar_electricity=Decimal('0.007'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='LTU', year=2017, biofuel_electricity=Decimal('0.504'), carbon_intensity_elec=Decimal('92.0'), coal_electricity=Decimal('0.0'), country='Lithuania', electricity_generation=Decimal('3.358'), fossil_electricity=Decimal('0.82'), gas_electricity=Decimal('0.598'), hydro_electricity=Decimal('0.602'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.223'), other_renewable_electricity=Decimal('0.504'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('2.538'), solar_electricity=Decimal('0.068'), wind_electricity=Decimal('1.364')),
#  Row(iso_code='BTN', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Bhutan', electricity_generation=Decimal('7.652'), fossil_electricity=Decimal('0.0'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('7.65'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('7.652'), solar_electricity=Decimal('0.001'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='AUS', year=2017, biofuel_electricity=Decimal('3.5'), carbon_intensity_elec=None, coal_electricity=Decimal('147.974'), country='Australia', electricity_generation=Decimal('244.716'), fossil_electricity=Decimal('204.51'), gas_electricity=Decimal('51.446'), hydro_electricity=Decimal('16.037'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('5.09'), other_renewable_electricity=Decimal('3.501'), other_renewable_exc_biofuel_electricity=Decimal('0.001'), renewables_electricity=Decimal('40.206'), solar_electricity=Decimal('8.071'), wind_electricity=Decimal('12.597')),
#  Row(iso_code='TKM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Turkmenistan', electricity_generation=Decimal('21.185'), fossil_electricity=Decimal('21.182'), gas_electricity=Decimal('7.23'), hydro_electricity=Decimal('0.003'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('13.952'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.003'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='PRT', year=2017, biofuel_electricity=Decimal('3.22'), carbon_intensity_elec=Decimal('353.0'), coal_electricity=Decimal('14.666'), country='Portugal', electricity_generation=Decimal('57.697'), fossil_electricity=Decimal('35.124'), gas_electricity=Decimal('18.895'), hydro_electricity=Decimal('5.897'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.563'), other_renewable_electricity=Decimal('3.437'), other_renewable_exc_biofuel_electricity=Decimal('0.217'), renewables_electricity=Decimal('22.573'), solar_electricity=Decimal('0.992'), wind_electricity=Decimal('12.248')),
#  Row(iso_code='UKR', year=2017, biofuel_electricity=Decimal('0.21'), carbon_intensity_elec=None, coal_electricity=Decimal('45.046'), country='Ukraine', electricity_generation=Decimal('145.681'), fossil_electricity=Decimal('54.486'), gas_electricity=Decimal('6.748'), hydro_electricity=Decimal('8.856'), nuclear_electricity=Decimal('80.406'), oil_electricity=Decimal('2.692'), other_renewable_electricity=Decimal('0.21'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('10.789'), solar_electricity=Decimal('0.74'), wind_electricity=Decimal('0.983')),
#  Row(iso_code='TUR', year=2017, biofuel_electricity=Decimal('2.124'), carbon_intensity_elec=None, coal_electricity=Decimal('91.257'), country='Turkey', electricity_generation=Decimal('283.086'), fossil_electricity=Decimal('196.615'), gas_electricity=Decimal('103.441'), hydro_electricity=Decimal('57.824'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.917'), other_renewable_electricity=Decimal('8.036'), other_renewable_exc_biofuel_electricity=Decimal('5.912'), renewables_electricity=Decimal('86.471'), solar_electricity=Decimal('2.818'), wind_electricity=Decimal('17.793')),
#  Row(iso_code='MAR', year=2017, biofuel_electricity=Decimal('0.013'), carbon_intensity_elec=None, coal_electricity=Decimal('13.569'), country='Morocco', electricity_generation=Decimal('29.899'), fossil_electricity=Decimal('25.262'), gas_electricity=Decimal('7.974'), hydro_electricity=Decimal('1.173'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('3.72'), other_renewable_electricity=Decimal('0.013'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('4.636'), solar_electricity=Decimal('0.415'), wind_electricity=Decimal('3.035')),
#  Row(iso_code='MOZ', year=2017, biofuel_electricity=Decimal('0.058'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Mozambique', electricity_generation=Decimal('16.734'), fossil_electricity=Decimal('2.754'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('13.92'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('2.754'), other_renewable_electricity=Decimal('0.058'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('13.98'), solar_electricity=Decimal('0.002'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ATG', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Antigua and Barbuda', electricity_generation=Decimal('0.329'), fossil_electricity=Decimal('0.323'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.323'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.006'), solar_electricity=Decimal('0.006'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='IRN', year=2017, biofuel_electricity=Decimal('0.024'), carbon_intensity_elec=None, coal_electricity=Decimal('0.598'), country='Iran', electricity_generation=Decimal('289.57'), fossil_electricity=Decimal('267.889'), gas_electricity=Decimal('239.733'), hydro_electricity=Decimal('14.9'), nuclear_electricity=Decimal('6.366'), oil_electricity=Decimal('27.558'), other_renewable_electricity=Decimal('0.024'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('15.315'), solar_electricity=Decimal('0.085'), wind_electricity=Decimal('0.306')),
#  Row(iso_code='NLD', year=2017, biofuel_electricity=Decimal('4.599'), carbon_intensity_elec=Decimal('459.0'), coal_electricity=Decimal('31.276'), country='Netherlands', electricity_generation=Decimal('117.137'), fossil_electricity=Decimal('96.298'), gas_electricity=Decimal('59.394'), hydro_electricity=Decimal('0.061'), nuclear_electricity=Decimal('3.402'), oil_electricity=Decimal('5.629'), other_renewable_electricity=Decimal('4.599'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('17.437'), solar_electricity=Decimal('2.208'), wind_electricity=Decimal('10.569')),
#  Row(iso_code='ISR', year=2017, biofuel_electricity=Decimal('0.171'), carbon_intensity_elec=None, coal_electricity=Decimal('21.283'), country='Israel', electricity_generation=Decimal('63.526'), fossil_electricity=Decimal('61.797'), gas_electricity=Decimal('40.513'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.171'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.729'), solar_electricity=Decimal('1.511'), wind_electricity=Decimal('0.047')),
#  Row(iso_code='PRK', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('2.821'), country='North Korea', electricity_generation=Decimal('14.617'), fossil_electricity=Decimal('2.821'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('11.781'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('11.796'), solar_electricity=Decimal('0.014'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='GHA', year=2017, biofuel_electricity=Decimal('0.017'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Ghana', electricity_generation=Decimal('10.885'), fossil_electricity=Decimal('5.28'), gas_electricity=Decimal('5.28'), hydro_electricity=Decimal('5.56'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.017'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('5.605'), solar_electricity=Decimal('0.028'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='BRN', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Brunei', electricity_generation=Decimal('3.908'), fossil_electricity=Decimal('3.906'), gas_electricity=Decimal('3.906'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.002'), solar_electricity=Decimal('0.002'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='PRY', year=2017, biofuel_electricity=Decimal('0.682'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Paraguay', electricity_generation=Decimal('59.771'), fossil_electricity=Decimal('0.002'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('59.087'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.002'), other_renewable_electricity=Decimal('0.682'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('59.769'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='GBR', year=2017, biofuel_electricity=Decimal('30.024'), carbon_intensity_elec=Decimal('264.0'), coal_electricity=Decimal('22.53'), country='United Kingdom', electricity_generation=Decimal('333.231'), fossil_electricity=Decimal('165.857'), gas_electricity=Decimal('136.746'), hydro_electricity=Decimal('5.902'), nuclear_electricity=Decimal('70.336'), oil_electricity=Decimal('6.58'), other_renewable_electricity=Decimal('30.028'), other_renewable_exc_biofuel_electricity=Decimal('0.004'), renewables_electricity=Decimal('97.038'), solar_electricity=Decimal('11.475'), wind_electricity=Decimal('49.633')),
#  Row(iso_code='KIR', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Kiribati', electricity_generation=Decimal('0.03'), fossil_electricity=Decimal('0.025'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.025'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.005'), solar_electricity=Decimal('0.005'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='CAF', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Central African Republic', electricity_generation=Decimal('0.151'), fossil_electricity=Decimal('0.001'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.15'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.001'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.15'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='KGZ', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('1.147'), country='Kyrgyzstan', electricity_generation=Decimal('15.293'), fossil_electricity=Decimal('1.232'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('14.061'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.085'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('14.061'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ALB', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Albania', electricity_generation=Decimal('4.481'), fossil_electricity=Decimal('0.0'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('4.48'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('4.481'), solar_electricity=Decimal('0.001'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ZAF', year=2017, biofuel_electricity=Decimal('0.417'), carbon_intensity_elec=None, coal_electricity=Decimal('206.745'), country='South Africa', electricity_generation=Decimal('237.958'), fossil_electricity=Decimal('212.792'), gas_electricity=Decimal('1.754'), hydro_electricity=Decimal('0.802'), nuclear_electricity=Decimal('15.087'), oil_electricity=Decimal('4.293'), other_renewable_electricity=Decimal('0.417'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('10.079'), solar_electricity=Decimal('3.936'), wind_electricity=Decimal('4.924')),
#  Row(iso_code='MDA', year=2017, biofuel_electricity=Decimal('0.023'), carbon_intensity_elec=None, coal_electricity=Decimal('3.863'), country='Moldova', electricity_generation=Decimal('4.683'), fossil_electricity=Decimal('4.369'), gas_electricity=Decimal('0.506'), hydro_electricity=Decimal('0.282'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.023'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.314'), solar_electricity=Decimal('0.002'), wind_electricity=Decimal('0.007')),
#  Row(iso_code='DMA', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Dominica', electricity_generation=Decimal('0.083'), fossil_electricity=Decimal('0.055'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.027'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.055'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.028'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='HND', year=2017, biofuel_electricity=Decimal('0.905'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Honduras', electricity_generation=Decimal('9.0'), fossil_electricity=Decimal('3.443'), gas_electricity=Decimal('0.163'), hydro_electricity=Decimal('3.057'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('3.28'), other_renewable_electricity=Decimal('0.998'), other_renewable_exc_biofuel_electricity=Decimal('0.093'), renewables_electricity=Decimal('5.557'), solar_electricity=Decimal('0.924'), wind_electricity=Decimal('0.578')),
#  Row(iso_code='JAM', year=2017, biofuel_electricity=Decimal('0.025'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Jamaica', electricity_generation=Decimal('4.145'), fossil_electricity=Decimal('3.635'), gas_electricity=Decimal('0.607'), hydro_electricity=Decimal('0.152'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('3.028'), other_renewable_electricity=Decimal('0.025'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.51'), solar_electricity=Decimal('0.044'), wind_electricity=Decimal('0.289')),
#  Row(iso_code='GUF', year=2017, biofuel_electricity=Decimal('0.01'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='French Guiana', electricity_generation=Decimal('1.076'), fossil_electricity=Decimal('0.45'), gas_electricity=Decimal('0.314'), hydro_electricity=Decimal('0.564'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.136'), other_renewable_electricity=Decimal('0.01'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.626'), solar_electricity=Decimal('0.052'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='MYS', year=2017, biofuel_electricity=Decimal('0.839'), carbon_intensity_elec=None, coal_electricity=Decimal('66.718'), country='Malaysia', electricity_generation=Decimal('156.171'), fossil_electricity=Decimal('128.553'), gas_electricity=Decimal('60.193'), hydro_electricity=Decimal('26.449'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.643'), other_renewable_electricity=Decimal('0.839'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('27.618'), solar_electricity=Decimal('0.33'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='PER', year=2017, biofuel_electricity=Decimal('0.471'), carbon_intensity_elec=None, coal_electricity=Decimal('0.616'), country='Peru', electricity_generation=Decimal('51.116'), fossil_electricity=Decimal('20.515'), gas_electricity=Decimal('19.899'), hydro_electricity=Decimal('28.769'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.471'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('30.6'), solar_electricity=Decimal('0.287'), wind_electricity=Decimal('1.073')),
#  Row(iso_code='MLT', year=2017, biofuel_electricity=Decimal('0.01'), carbon_intensity_elec=Decimal('435.0'), coal_electricity=Decimal('0.0'), country='Malta', electricity_generation=Decimal('1.652'), fossil_electricity=Decimal('1.48'), gas_electricity=Decimal('1.287'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.193'), other_renewable_electricity=Decimal('0.01'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.172'), solar_electricity=Decimal('0.162'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='COG', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Congo', electricity_generation=Decimal('3.325'), fossil_electricity=Decimal('2.133'), gas_electricity=Decimal('1.761'), hydro_electricity=Decimal('1.191'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.372'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.192'), solar_electricity=Decimal('0.001'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='CRI', year=2017, biofuel_electricity=Decimal('0.184'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Costa Rica', electricity_generation=Decimal('11.219'), fossil_electricity=Decimal('0.035'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('8.59'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.035'), other_renewable_electricity=Decimal('1.302'), other_renewable_exc_biofuel_electricity=Decimal('1.118'), renewables_electricity=Decimal('11.184'), solar_electricity=Decimal('0.004'), wind_electricity=Decimal('1.288')),
#  Row(iso_code='MDG', year=2017, biofuel_electricity=Decimal('0.026'), carbon_intensity_elec=None, coal_electricity=Decimal('0.749'), country='Madagascar', electricity_generation=Decimal('2.217'), fossil_electricity=Decimal('1.386'), gas_electricity=Decimal('0.184'), hydro_electricity=Decimal('0.781'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.454'), other_renewable_electricity=Decimal('0.026'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.831'), solar_electricity=Decimal('0.023'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ARG', year=2017, biofuel_electricity=Decimal('1.389'), carbon_intensity_elec=None, coal_electricity=Decimal('2.202'), country='Argentina', electricity_generation=Decimal('138.208'), fossil_electricity=Decimal('99.016'), gas_electricity=Decimal('84.051'), hydro_electricity=Decimal('31.459'), nuclear_electricity=Decimal('5.716'), oil_electricity=Decimal('12.763'), other_renewable_electricity=Decimal('1.389'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('33.476'), solar_electricity=Decimal('0.016'), wind_electricity=Decimal('0.612')),
#  Row(iso_code='DOM', year=2017, biofuel_electricity=Decimal('0.153'), carbon_intensity_elec=None, coal_electricity=Decimal('3.16'), country='Dominican Republic', electricity_generation=Decimal('18.045'), fossil_electricity=Decimal('15.189'), gas_electricity=Decimal('3.305'), hydro_electricity=Decimal('2.174'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('8.724'), other_renewable_electricity=Decimal('0.153'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('2.856'), solar_electricity=Decimal('0.139'), wind_electricity=Decimal('0.39')),
#  Row(iso_code='IND', year=2017, biofuel_electricity=Decimal('13.478'), carbon_intensity_elec=None, coal_electricity=Decimal('972.939'), country='India', electricity_generation=Decimal('1285.739'), fossil_electricity=Decimal('1023.443'), gas_electricity=Decimal('50.256'), hydro_electricity=Decimal('135.865'), nuclear_electricity=Decimal('38.438'), oil_electricity=Decimal('0.249'), other_renewable_electricity=Decimal('13.819'), other_renewable_exc_biofuel_electricity=Decimal('0.34'), renewables_electricity=Decimal('223.857'), solar_electricity=Decimal('21.545'), wind_electricity=Decimal('52.629')),
#  Row(iso_code='COL', year=2017, biofuel_electricity=Decimal('1.427'), carbon_intensity_elec=None, coal_electricity=Decimal('5.195'), country='Colombia', electricity_generation=Decimal('77.681'), fossil_electricity=Decimal('15.417'), gas_electricity=Decimal('9.521'), hydro_electricity=Decimal('60.82'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.701'), other_renewable_electricity=Decimal('1.427'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('62.264'), solar_electricity=Decimal('0.014'), wind_electricity=Decimal('0.003')),
#  Row(iso_code='ASM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='American Samoa', electricity_generation=Decimal('0.167'), fossil_electricity=Decimal('0.167'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.167'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='KWT', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Kuwait', electricity_generation=Decimal('68.426'), fossil_electricity=Decimal('68.359'), gas_electricity=Decimal('68.359'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.067'), solar_electricity=Decimal('0.049'), wind_electricity=Decimal('0.018')),
#  Row(iso_code='ZWE', year=2017, biofuel_electricity=Decimal('0.151'), carbon_intensity_elec=None, coal_electricity=Decimal('3.219'), country='Zimbabwe', electricity_generation=Decimal('7.31'), fossil_electricity=Decimal('3.219'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('3.929'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.151'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('4.091'), solar_electricity=Decimal('0.011'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='LVA', year=2017, biofuel_electricity=Decimal('0.931'), carbon_intensity_elec=Decimal('65.0'), coal_electricity=Decimal('0.0'), country='Latvia', electricity_generation=Decimal('7.531'), fossil_electricity=Decimal('2.069'), gas_electricity=Decimal('2.069'), hydro_electricity=Decimal('4.381'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.931'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('5.462'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.15')),
#  Row(iso_code='LBR', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Liberia', electricity_generation=Decimal('0.376'), fossil_electricity=Decimal('0.373'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.373'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.003'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='QAT', year=2017, biofuel_electricity=Decimal('0.115'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Qatar', electricity_generation=Decimal('42.945'), fossil_electricity=Decimal('42.822'), gas_electricity=Decimal('42.822'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.115'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.123'), solar_electricity=Decimal('0.008'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='SDN', year=2017, biofuel_electricity=Decimal('0.117'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Sudan', electricity_generation=Decimal('15.214'), fossil_electricity=Decimal('5.823'), gas_electricity=Decimal('1.641'), hydro_electricity=Decimal('9.254'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('4.182'), other_renewable_electricity=Decimal('0.117'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('9.391'), solar_electricity=Decimal('0.02'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='JOR', year=2017, biofuel_electricity=Decimal('0.004'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Jordan', electricity_generation=Decimal('19.572'), fossil_electricity=Decimal('18.174'), gas_electricity=Decimal('16.495'), hydro_electricity=Decimal('0.038'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.679'), other_renewable_electricity=Decimal('0.004'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.398'), solar_electricity=Decimal('0.908'), wind_electricity=Decimal('0.448')),
#  Row(iso_code='GMB', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Gambia', electricity_generation=Decimal('0.306'), fossil_electricity=Decimal('0.303'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.303'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.003'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='NGA', year=2017, biofuel_electricity=Decimal('0.025'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Nigeria', electricity_generation=Decimal('32.794'), fossil_electricity=Decimal('25.069'), gas_electricity=Decimal('25.069'), hydro_electricity=Decimal('7.67'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.025'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('7.726'), solar_electricity=Decimal('0.028'), wind_electricity=Decimal('0.003')),
#  Row(iso_code='BHR', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Bahrain', electricity_generation=Decimal('27.481'), fossil_electricity=Decimal('27.471'), gas_electricity=Decimal('27.445'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.026'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.009'), solar_electricity=Decimal('0.008'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='TGO', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Togo', electricity_generation=Decimal('0.664'), fossil_electricity=Decimal('0.559'), gas_electricity=Decimal('0.122'), hydro_electricity=Decimal('0.102'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.437'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.105'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='POL', year=2017, biofuel_electricity=Decimal('6.488'), carbon_intensity_elec=Decimal('784.0'), coal_electricity=Decimal('131.159'), country='Poland', electricity_generation=Decimal('169.929'), fossil_electricity=Decimal('145.807'), gas_electricity=Decimal('10.035'), hydro_electricity=Decimal('2.56'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('4.614'), other_renewable_electricity=Decimal('6.488'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('24.122'), solar_electricity=Decimal('0.165'), wind_electricity=Decimal('14.909')),
#  Row(iso_code='SAU', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Saudi Arabia', electricity_generation=Decimal('355.61'), fossil_electricity=Decimal('355.451'), gas_electricity=Decimal('188.734'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('166.717'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.16'), solar_electricity=Decimal('0.155'), wind_electricity=Decimal('0.005')),
#  Row(iso_code='WSM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Samoa', electricity_generation=Decimal('0.127'), fossil_electricity=Decimal('0.092'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.035'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.092'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.035'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='GUM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Guam', electricity_generation=Decimal('1.757'), fossil_electricity=Decimal('1.697'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.697'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.06'), solar_electricity=Decimal('0.06'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='MRT', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Mauritania', electricity_generation=Decimal('0.978'), fossil_electricity=Decimal('0.643'), gas_electricity=Decimal('0.305'), hydro_electricity=Decimal('0.174'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.338'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.335'), solar_electricity=Decimal('0.057'), wind_electricity=Decimal('0.104')),
#  Row(iso_code='TCD', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Chad', electricity_generation=Decimal('0.225'), fossil_electricity=Decimal('0.216'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.216'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.009'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.009')),
#  Row(iso_code='MUS', year=2017, biofuel_electricity=Decimal('0.48'), carbon_intensity_elec=None, coal_electricity=Decimal('0.728'), country='Mauritius', electricity_generation=Decimal('2.97'), fossil_electricity=Decimal('2.347'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.089'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.619'), other_renewable_electricity=Decimal('0.48'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.623'), solar_electricity=Decimal('0.039'), wind_electricity=Decimal('0.015')),
#  Row(iso_code='MWI', year=2017, biofuel_electricity=Decimal('0.053'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Malawi', electricity_generation=Decimal('2.087'), fossil_electricity=Decimal('0.172'), gas_electricity=Decimal('0.172'), hydro_electricity=Decimal('1.823'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.053'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.915'), solar_electricity=Decimal('0.039'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='SYC', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Seychelles', electricity_generation=Decimal('0.427'), fossil_electricity=Decimal('0.424'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.424'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.003'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='GEO', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Georgia', electricity_generation=Decimal('11.305'), fossil_electricity=Decimal('2.099'), gas_electricity=Decimal('2.099'), hydro_electricity=Decimal('9.118'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('9.206'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.088')),
#  Row(iso_code='RWA', year=2017, biofuel_electricity=Decimal('0.002'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Rwanda', electricity_generation=Decimal('0.753'), fossil_electricity=Decimal('0.332'), gas_electricity=Decimal('0.16'), hydro_electricity=Decimal('0.325'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.172'), other_renewable_electricity=Decimal('0.002'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.421'), solar_electricity=Decimal('0.094'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='SSD', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='South Sudan', electricity_generation=Decimal('0.51'), fossil_electricity=Decimal('0.507'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.507'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.003'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ISL', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Iceland', electricity_generation=Decimal('18.846'), fossil_electricity=Decimal('0.002'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('13.892'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.002'), other_renewable_electricity=Decimal('4.944'), other_renewable_exc_biofuel_electricity=Decimal('4.944'), renewables_electricity=Decimal('18.844'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.008')),
#  Row(iso_code='FRA', year=2017, biofuel_electricity=Decimal('7.766'), carbon_intensity_elec=Decimal('69.0'), coal_electricity=Decimal('12.818'), country='France', electricity_generation=Decimal('556.077'), fossil_electricity=Decimal('65.101'), gas_electricity=Decimal('40.5'), hydro_electricity=Decimal('50.001'), nuclear_electricity=Decimal('398.359'), oil_electricity=Decimal('11.783'), other_renewable_electricity=Decimal('8.421'), other_renewable_exc_biofuel_electricity=Decimal('0.655'), renewables_electricity=Decimal('92.617'), solar_electricity=Decimal('9.585'), wind_electricity=Decimal('24.609')),
# ...
#  Row(iso_code='NAM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.041'), country='Namibia', electricity_generation=Decimal('1.67'), fossil_electricity=Decimal('0.062'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('1.577'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.021'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('1.608'), solar_electricity=Decimal('0.026'), wind_electricity=Decimal('0.005')),
#  Row(iso_code='SOM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Somalia', electricity_generation=Decimal('0.347'), fossil_electricity=Decimal('0.33'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.33'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.017'), solar_electricity=Decimal('0.011'), wind_electricity=Decimal('0.006')),
#  Row(iso_code='COK', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Cook Islands', electricity_generation=Decimal('0.037'), fossil_electricity=Decimal('0.031'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.031'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.006'), solar_electricity=Decimal('0.006'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='JPN', year=2017, biofuel_electricity=Decimal('40.475'), carbon_intensity_elec=None, coal_electricity=Decimal('300.87'), country='Japan', electricity_generation=Decimal('992.688'), fossil_electricity=Decimal('772.728'), gas_electricity=Decimal('363.903'), hydro_electricity=Decimal('83.417'), nuclear_electricity=Decimal('11.61'), oil_electricity=Decimal('107.955'), other_renewable_electricity=Decimal('63.374'), other_renewable_exc_biofuel_electricity=Decimal('22.899'), renewables_electricity=Decimal('208.35'), solar_electricity=Decimal('55.069'), wind_electricity=Decimal('6.49')),
#  Row(iso_code='GNQ', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Equatorial Guinea', electricity_generation=Decimal('1.276'), fossil_electricity=Decimal('0.842'), gas_electricity=Decimal('0.842'), hydro_electricity=Decimal('0.434'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.434'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='HRV', year=2017, biofuel_electricity=Decimal('0.526'), carbon_intensity_elec=Decimal('195.0'), coal_electricity=Decimal('1.367'), country='Croatia', electricity_generation=Decimal('11.783'), fossil_electricity=Decimal('4.668'), gas_electricity=Decimal('3.09'), hydro_electricity=Decimal('5.307'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.21'), other_renewable_electricity=Decimal('0.526'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('7.116'), solar_electricity=Decimal('0.079'), wind_electricity=Decimal('1.204')),
#  Row(iso_code='MDV', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Maldives', electricity_generation=Decimal('0.604'), fossil_electricity=Decimal('0.602'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.602'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.002'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.002')),
#  Row(iso_code='TWN', year=2017, biofuel_electricity=Decimal('3.529'), carbon_intensity_elec=None, coal_electricity=Decimal('117.732'), country='Taiwan', electricity_generation=Decimal('252.134'), fossil_electricity=Decimal('218.185'), gas_electricity=Decimal('84.172'), hydro_electricity=Decimal('5.446'), nuclear_electricity=Decimal('21.56'), oil_electricity=Decimal('16.281'), other_renewable_electricity=Decimal('3.529'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('12.389'), solar_electricity=Decimal('1.692'), wind_electricity=Decimal('1.722')),
#  Row(iso_code='HTI', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Haiti', electricity_generation=Decimal('0.999'), fossil_electricity=Decimal('0.872'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.126'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.872'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.127'), solar_electricity=Decimal('0.001'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='ECU', year=2017, biofuel_electricity=Decimal('0.459'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Ecuador', electricity_generation=Decimal('27.391'), fossil_electricity=Decimal('6.935'), gas_electricity=Decimal('3.488'), hydro_electricity=Decimal('19.887'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('3.448'), other_renewable_electricity=Decimal('0.459'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('20.456'), solar_electricity=Decimal('0.037'), wind_electricity=Decimal('0.073')),
#  Row(iso_code='AUT', year=2017, biofuel_electricity=Decimal('4.921'), carbon_intensity_elec=Decimal('107.0'), coal_electricity=Decimal('1.758'), country='Austria', electricity_generation=Decimal('67.43'), fossil_electricity=Decimal('16.375'), gas_electricity=Decimal('10.914'), hydro_electricity=Decimal('38.294'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('3.703'), other_renewable_electricity=Decimal('4.921'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('51.055'), solar_electricity=Decimal('1.269'), wind_electricity=Decimal('6.572')),
#  Row(iso_code='THA', year=2017, biofuel_electricity=Decimal('15.442'), carbon_intensity_elec=None, coal_electricity=Decimal('33.336'), country='Thailand', electricity_generation=Decimal('172.312'), fossil_electricity=Decimal('146.569'), gas_electricity=Decimal('112.925'), hydro_electricity=Decimal('4.647'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.308'), other_renewable_electricity=Decimal('15.444'), other_renewable_exc_biofuel_electricity=Decimal('0.002'), renewables_electricity=Decimal('25.743'), solar_electricity=Decimal('4.543'), wind_electricity=Decimal('1.109')),
#  Row(iso_code='ROU', year=2017, biofuel_electricity=Decimal('0.525'), carbon_intensity_elec=Decimal('315.0'), coal_electricity=Decimal('16.78'), country='Romania', electricity_generation=Decimal('63.937'), fossil_electricity=Decimal('28.146'), gas_electricity=Decimal('10.656'), hydro_electricity=Decimal('14.494'), nuclear_electricity=Decimal('11.509'), oil_electricity=Decimal('0.71'), other_renewable_electricity=Decimal('0.525'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('24.282'), solar_electricity=Decimal('1.856'), wind_electricity=Decimal('7.407')),
#  Row(iso_code='SLB', year=2017, biofuel_electricity=Decimal('0.004'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Solomon Islands', electricity_generation=Decimal('0.105'), fossil_electricity=Decimal('0.098'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.098'), other_renewable_electricity=Decimal('0.004'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.007'), solar_electricity=Decimal('0.003'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='GRC', year=2017, biofuel_electricity=Decimal('0.31'), carbon_intensity_elec=Decimal('658.0'), coal_electricity=Decimal('18.765'), country='Greece', electricity_generation=Decimal('55.189'), fossil_electricity=Decimal('41.388'), gas_electricity=Decimal('17.128'), hydro_electricity=Decimal('3.963'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('5.495'), other_renewable_electricity=Decimal('0.31'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('13.801'), solar_electricity=Decimal('3.991'), wind_electricity=Decimal('5.537')),
#  Row(iso_code='COM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Comoros', electricity_generation=Decimal('0.086'), fossil_electricity=Decimal('0.086'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.086'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='NIC', year=2017, biofuel_electricity=Decimal('0.666'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Nicaragua', electricity_generation=Decimal('4.401'), fossil_electricity=Decimal('1.872'), gas_electricity=Decimal('0.258'), hydro_electricity=Decimal('0.463'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.614'), other_renewable_electricity=Decimal('1.417'), other_renewable_exc_biofuel_electricity=Decimal('0.751'), renewables_electricity=Decimal('2.529'), solar_electricity=Decimal('0.014'), wind_electricity=Decimal('0.635')),
#  Row(iso_code='FIN', year=2017, biofuel_electricity=Decimal('11.862'), carbon_intensity_elec=Decimal('99.0'), coal_electricity=Decimal('5.857'), country='Finland', electricity_generation=Decimal('67.124'), fossil_electricity=Decimal('13.17'), gas_electricity=Decimal('3.3'), hydro_electricity=Decimal('14.771'), nuclear_electricity=Decimal('22.477'), oil_electricity=Decimal('4.013'), other_renewable_electricity=Decimal('11.862'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('31.477'), solar_electricity=Decimal('0.049'), wind_electricity=Decimal('4.795')),
#  Row(iso_code='CYM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Cayman Islands', electricity_generation=Decimal('0.668'), fossil_electricity=Decimal('0.654'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.654'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.014'), solar_electricity=Decimal('0.014'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='BLZ', year=2017, biofuel_electricity=Decimal('0.12'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Belize', electricity_generation=Decimal('0.405'), fossil_electricity=Decimal('0.016'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.268'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.016'), other_renewable_electricity=Decimal('0.12'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.389'), solar_electricity=Decimal('0.001'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='BIH', year=2017, biofuel_electricity=Decimal('0.006'), carbon_intensity_elec=None, coal_electricity=Decimal('11.679'), country='Bosnia and Herzegovina', electricity_generation=Decimal('15.459'), fossil_electricity=Decimal('11.679'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('3.752'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.0'), other_renewable_electricity=Decimal('0.006'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('3.78'), solar_electricity=Decimal('0.021'), wind_electricity=Decimal('0.001')),
#  Row(iso_code='SPM', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Saint Pierre and Miquelon', electricity_generation=Decimal('0.046'), fossil_electricity=Decimal('0.046'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.046'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='CMR', year=2017, biofuel_electricity=Decimal('0.038'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Cameroon', electricity_generation=Decimal('7.871'), fossil_electricity=Decimal('2.778'), gas_electricity=Decimal('2.21'), hydro_electricity=Decimal('5.039'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.568'), other_renewable_electricity=Decimal('0.038'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('5.093'), solar_electricity=Decimal('0.016'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='GTM', year=2017, biofuel_electricity=Decimal('2.508'), carbon_intensity_elec=None, coal_electricity=Decimal('1.338'), country='Guatemala', electricity_generation=Decimal('12.622'), fossil_electricity=Decimal('3.638'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('5.806'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('2.3'), other_renewable_electricity=Decimal('2.761'), other_renewable_exc_biofuel_electricity=Decimal('0.253'), renewables_electricity=Decimal('8.984'), solar_electricity=Decimal('0.199'), wind_electricity=Decimal('0.218')),
#  Row(iso_code='SHN', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Saint Helena', electricity_generation=Decimal('0.008'), fossil_electricity=Decimal('0.008'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('0.008'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0')),
#  Row(iso_code='CYP', year=2017, biofuel_electricity=Decimal('0.052'), carbon_intensity_elec=Decimal('661.0'), coal_electricity=Decimal('0.0'), country='Cyprus', electricity_generation=Decimal('5.004'), fossil_electricity=Decimal('4.569'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('4.569'), other_renewable_electricity=Decimal('0.052'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.435'), solar_electricity=Decimal('0.172'), wind_electricity=Decimal('0.211')),
#  Row(iso_code='MAC', year=2017, biofuel_electricity=Decimal('0.0'), carbon_intensity_elec=None, coal_electricity=Decimal('0.0'), country='Macau', electricity_generation=Decimal('1.377'), fossil_electricity=Decimal('1.377'), gas_electricity=Decimal('0.0'), hydro_electricity=Decimal('0.0'), nuclear_electricity=Decimal('0.0'), oil_electricity=Decimal('1.377'), other_renewable_electricity=Decimal('0.0'), other_renewable_exc_biofuel_electricity=Decimal('0.0'), renewables_electricity=Decimal('0.0'), solar_electricity=Decimal('0.0'), wind_electricity=Decimal('0.0'))]
